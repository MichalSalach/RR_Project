# %% [markdown]
# ### Scraping live betting odds from [flashscore.pl/tenis](https://www.flashscore.pl/tenis/)

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup as BS
import re
import requests
import json
from datetime import datetime
from datetime import timedelta
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 40)

# %%
# Prepare a data frame
data = pd.DataFrame(columns = ['event', 'match_time', 'player_1', 'player_2', 
                               'player_1_score_sets', 'player_1_score_games', 'player_1_score_points',
                               'player_2_score_sets', 'player_2_score_games', 'player_2_score_points', 
                               'serving',
                               'player_1_nationality', 'player_2_nationality', 
                               'player_1_rank', 'player_2_rank',
                               'player_1_link', 'player_2_link',
                               'player_1_eFortuna', 'player_2_eFortuna',
                               'player_1_STS', 'player_2_STS',
                               'player_1_Betclic', 'player_2_Betclic',
                               'player_1_Betfan', 'player_2_Betfan',
                               'player_1_Pzbuk', 'player_2_Pzbuk',
                               'player_1_Lvbet', 'player_2_Lvbet',
                               'player_1_Totolotek', 'player_2_Totolotek'
                              ])

# Retrieve data file for the main page for today's matches, including current scores
headers = {"Accept":  "*/*",
           "Accept-Encoding": "gzip, deflate, br",
           "Accept-Language": "pl,en-US;q=0.7,en;q=0.3",
           "Connection": "keep-alive",
           "Host": "d.flashscore.pl",
           "Referer": "https://d.flashscore.pl/x/feed/proxy-fetch",
           "TE": "Trailers",
           "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:88.0) Gecko/20100101 Firefox/88.0",
           "x-fsign": "SW9D1eZo"
          }

s = requests.Session()

main_page = s.get('https://d.flashscore.pl/x/feed/f_2_0_2_pl_1', 
                        headers = headers)

# Split the data for the matches (Note: the 1st element of `matches` will not be a match, but we do not worry, 
# because this element will be filtered out in the next step.)
matches = re.split('¬~AA÷', main_page.text)

# It seems that that the ended/cancelled/interrupted matches contain the tag '¬AB÷3', the current ones - '¬AB÷2', 
# and the future ones - '¬AB÷1'. We will keep only those matches, for which there are active/future bets.
matches = [match for match in matches if '¬AB÷1' in match or '¬AB÷2' in match]

for match in matches:
    
    new_row = {}
    
    # Retrieve match ID that will be used for retriving detailed information for the match (betting odds)
    match_id = re.search('.*?¬AD÷', match).group()[:-4]
    url = 'https://www.flashscore.pl/mecz/' + match_id + '/#zestawienie-kursow/home-away/koniec-meczu'
    
    # Retrieve match time
    # Add 2 hours (time zone difference).
    match_time = re.search('¬AD÷.*?¬ADE÷', match).group()[4:-5]
    match_time = datetime.utcfromtimestamp(int(match_time))
    match_time = match_time + timedelta(hours = 2)
    new_row['match_time'] = match_time.strftime('%d-%m-%Y %H:%M:%S')
    
    # Retrieve current match score from the file (if match not started, NoType object is found)
    player_1_score = re.search('¬AG÷.*?¬OA÷', match)
    player_2_score = re.search('¬AH÷.*?¬OB÷', match)
    
    # Strip the score from unnecesary symbols and split it into sets, games and points
    if player_1_score:
        player_1_score = player_1_score.group()[4:-4]
        # (Possibly remove the part of the score accounting for tie-break points.)
        player_1_score = re.sub('¬D.÷\d+', '', player_1_score)
        player_1_score = re.split('¬.*?÷', player_1_score)
        new_row['player_1_score_sets'] = player_1_score[0]
        new_row['player_1_score_games'] = ' '.join(map(str, player_1_score[1:-1]))
        new_row['player_1_score_points'] = player_1_score[-1]

    else:
        new_row['player_1_score_sets'] = 0
        new_row['player_1_score_games'] = ''
        new_row['player_1_score_points'] = ''

    if player_2_score:
        player_2_score = player_2_score.group()[4:-4]
        player_2_score = re.sub('¬D.÷\d+', '', player_2_score)
        player_2_score = re.split('¬.*?÷', player_2_score)
        new_row['player_2_score_sets'] = player_2_score[0]
        new_row['player_2_score_games'] = ' '.join(map(str, player_2_score[1:-1]))
        new_row['player_2_score_points'] = player_2_score[-1]

    else:
        new_row['player_2_score_sets'] = 0
        new_row['player_2_score_games'] = ''
        new_row['player_2_score_points'] = ''
        
    # Retrieve information on who is serving right now. It seems that '¬WC÷1' signifies that it is the 1st player,
    # and '¬WC÷2' - the 2nd player.
    if '¬WC÷1' in match:
        new_row['serving'] = 'player_1'
    elif '¬WC÷2' in match:
        new_row['serving'] = 'player_2'
    else:
        new_row['serving'] = np.nan
        
    try:
        html = s.get(url)
        match_page = BS(html.content, 'html.parser')
        
        # Retrieve the event title from the the match's site
        new_row['event'] = match_page.head.find_all('meta')[5]['content']
        
        # Retrieve players' names
        players = match_page.head.find_all('meta')[4]['content']
        players = re.split(' - ', players)
        new_row['player_1'] = players[0]
        new_row['player_2'] = players[1]
        
        # Retrieve a JSON part containing some details on the players
        script = match_page.find_all('script')[1].string
        script = re.search('\{.*\}', script).group()
        details = json.loads(script)
        
        details_player_1 = details['participantsData']['home']
        details_player_2 = details['participantsData']['away']
        
        # Retrieve players' nationality
        # In the case of doubles, seprate the information by ' / '.
        new_row['player_1_nationality'] = ' / '.join([player['country'] for player in details_player_1])
        new_row['player_2_nationality'] = ' / '.join([player['country'] for player in details_player_2])

        # Retrieve players' rankings
        # In the case of doubles, seprate the information by ' / '.
        new_row['player_1_rank'] = ' / '.join([player['rank'][1] if player['rank']!=[] else '' for player \
                                               in details_player_1])
        new_row['player_2_rank'] = ' / '.join([player['rank'][1] if player['rank']!=[] else '' for player \
                                               in details_player_2])
        
        # Retrieve links to players' pages on flashscore.pl
        # In the case of doubles, seprate the information by ' / '.
        new_row['player_1_link'] = ' / '.join(['https://www.flashscore.pl' + player['detail_link'] for player \
                                               in details_player_1]) 
        new_row['player_2_link'] = ' / '.join(['https://www.flashscore.pl' + player['detail_link'] for player \
                                               in details_player_2])

        
    except:
        new_row['event'] = np.nan
        # (For players' names and nationalities we can use another method of retrieving this information, 
        # not using the match_page, but the main_page).
        details_player_1 = re.search('¬AE÷.*?¬JA÷', match).group()[4:-4]
        details_player_2 = re.search('¬AF÷.*?¬JB÷', match).group()[4:-4]
        details_player_1 = re.split(' \(', details_player_1)
        details_player_2 = re.split(' \(', details_player_2)
        
        new_row['player_1'] = details_player_1[0]
        new_row['player_2'] = details_player_2[0]
        # (We need to distinguish singles - players' nationalities is given on the main page - and doubles
        # - nationalities not given).
        if len(details_player_1)==2:
            new_row['player_1_nationality'] = details_player_1[1][:-1]
        else:
            new_row['player_1_nationality'] = np.nan
        if len(details_player_2)==2:
            new_row['player_2_nationality'] = details_player_2[1][:-1]
        else:
            new_row['player_2_nationality'] = np.nan
        
        new_row['player_1_rank'] = np.nan
        new_row['player_2_rank'] = np.nan
        new_row['player_1_link'] = np.nan
        new_row['player_2_link'] = np.nan
        
        
    try:
        # Retrieve a file including betting odds from the match's site
        match_odds = s.get('https://d.flashscore.pl/x/feed/df_od_1_' + match_id, headers = headers)

        # Retrieve the part of data including end of match betting odds
        match_odds = re.search('(home-away).*?(Set 1)', match_odds.text).group()
        
        # It seems that invalid (crossed-out) odds are those that end up with '¬OG÷0', and the valid ones
        # end up with '¬OG÷1'.
        match_odds = re.findall('¬OD÷.*?¬OG÷.', match_odds)
        valid_odds = ''.join([o for o in match_odds if o[-1]=='1'])

        # Retrieve the lists of the bookmakers' names and the odds
        bookmakers = re.findall('¬OD.*?¬OPI', valid_odds)
        player_1_odds = re.findall('¬XB÷.*?¬XC', valid_odds) 
        player_2_odds = re.findall('¬XC÷.*?¬OG', valid_odds)
        
        # Strip the bookmakers names from unnecessary symbols
        bookmakers = [i[4:-4] for i in bookmakers]
        
        # Strip the odds data from unnecessary symbols, split on the last change of the odds, 
        # and take the last value
        player_1_odds = [re.split('\[.\]', i[4:-3])[-1] for i in player_1_odds]
        player_2_odds = [re.split('\[.\]', i[4:-3])[-1] for i in player_2_odds]
        
        # Assign betting odds for 7 possible bookmakers, for both players.
        # (Regex is used to produce an appropriate form of a variable (column name).)
        for bookmaker in ['eFortuna.pl', 'STS.pl', 'Betclic.pl', 'Betfan.pl', 
                          'Lvbet.pl', 'Pzbukpl', 'Totolotek.pl']:
            
            try:
                new_row['player_1_' + re.search('\w*(?=[\.p])', bookmaker).group()] = \
                player_1_odds[bookmakers.index(bookmaker)]
            except:
                new_row['player_1_' + re.search('\w*(?=[\.p])', bookmaker).group()] = np.nan

            try:
                new_row['player_2_' + re.search('\w*(?=[\.p])', bookmaker).group()] = \
                player_2_odds[bookmakers.index(bookmaker)]
            except:
                new_row['player_2_' + re.search('\w*(?=[\.p])', bookmaker).group()] = np.nan
            
    except:
        
        for bookmaker in ['eFortuna.pl', 'STS.pl', 'Betclic.pl', 'Betfan.pl', 
                          'Lvbet.pl', 'Pzbukpl', 'Totolotek.pl']:
            
            new_row['player_1_' + re.search('\w*(?=[\.p])', bookmaker).group()] = np.nan
            new_row['player_2_' + re.search('\w*(?=[\.p])', bookmaker).group()] = np.nan
            
    data = data.append(new_row, ignore_index = True)

scraping_time = datetime.now()

# %%
data
# Out:
#                                                 event           match_time  \
# 0   ATP - SINGIEL: Belgrade 2 (Serbia), ziemna - Ć...  27-05-2021 15:30:00
# 1   ATP - SINGIEL: Belgrade 2 (Serbia), ziemna - Ć...  27-05-2021 17:00:00
# 2   ATP - SINGIEL: French Open (Francja) - Kwalifi...  27-05-2021 15:35:00
# 3   ATP - SINGIEL: French Open (Francja) - Kwalifi...  27-05-2021 15:35:00
# 4   ATP - SINGIEL: Parma (Włochy), ziemna - Ćwierć...  27-05-2021 16:00:00
# 5   WTA - SINGIEL: French Open (Francja) - Kwalifi...  27-05-2021 14:50:00
# 6   WTA - SINGIEL: French Open (Francja) - Kwalifi...  27-05-2021 15:40:00
# 7   WTA - SINGIEL: Strasbourg (Francja), ziemna - ...  27-05-2021 15:05:00
# 8   WTA - SINGIEL: Strasbourg (Francja), ziemna - ...  27-05-2021 17:30:00
# 9   ATP - DEBEL: Belgrade 2 (Serbia), ziemna - Pół...  27-05-2021 15:00:00
# 10  ATP - DEBEL: Parma (Włochy), ziemna - Ćwierćfinał  27-05-2021 15:10:00
# 11  CHALLENGER MĘŻCZYŹNI - SINGIEL: Oeiras 4 (Port...  27-05-2021 14:05:00
# 12  CHALLENGER MĘŻCZYŹNI - SINGIEL: Oeiras 4 (Port...  27-05-2021 15:40:00
# 13  CHALLENGER MĘŻCZYŹNI - SINGIEL: Oeiras 4 (Port...  27-05-2021 16:15:00
# 14  CHALLENGER MĘŻCZYŹNI - DEBEL: Oeiras 4 (Portug...  27-05-2021 17:15:00
# 15  CHALLENGER MĘŻCZYŹNI - DEBEL: Oeiras 4 (Portug...  27-05-2021 17:50:00
# 16  CHALLENGER MĘŻCZYŹNI - DEBEL: Oeiras 4 (Portug...  27-05-2021 18:45:00
# 17  ITF MĘŻCZYŹNI - SINGIEL: M15 Kouvola (Finlandi...  27-05-2021 14:30:00
# 18  ITF MĘŻCZYŹNI - SINGIEL: M15 Kouvola (Finlandi...  27-05-2021 14:40:00
# 19  ITF MĘŻCZYŹNI - SINGIEL: M15 Monastir 14 (Tune...  27-05-2021 13:50:00
# 20  ITF MĘŻCZYŹNI - SINGIEL: M15 Monastir 14 (Tune...  27-05-2021 15:00:00
# 21  ITF MĘŻCZYŹNI - SINGIEL: M25 Kiseljak (Bośnia ...  27-05-2021 15:30:00
# 22  ITF MĘŻCZYŹNI - SINGIEL: M25 Kiseljak (Bośnia ...  27-05-2021 17:30:00
# 23  ITF KOBIETY - SINGIEL: W15 Monastir 14 (Tunezj...  27-05-2021 14:00:00
# 24  ITF KOBIETY - SINGIEL: W15 Monastir 14 (Tunezj...  27-05-2021 14:45:00
# 25  ITF KOBIETY - SINGIEL: W15 Santa Margarita de ...  27-05-2021 13:00:00
# 26  ITF KOBIETY - SINGIEL: W15 Santa Margarita de ...  27-05-2021 15:00:00
# 27  ITF KOBIETY - SINGIEL: W15 Santa Margarita de ...  27-05-2021 15:00:00
# 28  ITF KOBIETY - SINGIEL: W15 Sibenik 2 (Chorwacj...  27-05-2021 15:00:00
# 29  ITF KOBIETY - SINGIEL: W15 Sibenik 2 (Chorwacj...  27-05-2021 15:00:00
# 30  ITF KOBIETY - SINGIEL: W25 Otocec (Słowenia), ...  27-05-2021 14:20:00
# 31  ITF KOBIETY - SINGIEL: W25 Otocec (Słowenia), ...  27-05-2021 16:00:00
# 32  ITF MĘŻCZYŹNI - DEBEL: M15 Antalya (Turcja), z...  27-05-2021 14:00:00
# 33  ITF MĘŻCZYŹNI - DEBEL: M15 Antalya (Turcja), z...  27-05-2021 14:00:00
# 34  ITF MĘŻCZYŹNI - DEBEL: M15 Bucharest (Rumunia)...  27-05-2021 14:00:00
# 35  ITF MĘŻCZYŹNI - DEBEL: M15 Bucharest (Rumunia)...  27-05-2021 14:00:00
# 36  ITF MĘŻCZYŹNI - DEBEL: M15 Bucharest (Rumunia)...  27-05-2021 14:00:00
# 37  ITF MĘŻCZYŹNI - DEBEL: M15 Bucharest (Rumunia)...  27-05-2021 15:00:00
# 38  ITF MĘŻCZYŹNI - DEBEL: M15 Heraklion 8 (Grecja...  27-05-2021 15:00:00
# 39  ITF MĘŻCZYŹNI - DEBEL: M15 Kouvola (Finlandia)...  27-05-2021 15:00:00
# 40  ITF MĘŻCZYŹNI - DEBEL: M15 Kouvola (Finlandia)...  27-05-2021 15:00:00
# 41  ITF MĘŻCZYŹNI - DEBEL: M15 Kouvola (Finlandia)...  27-05-2021 16:00:00
# 42  ITF MĘŻCZYŹNI - DEBEL: M15 Kouvola (Finlandia)...  27-05-2021 16:00:00
# 43  ITF MĘŻCZYŹNI - DEBEL: M15 Monastir (Tunezja),...  27-05-2021 14:30:00
# 44  ITF MĘŻCZYŹNI - DEBEL: M15 Monastir (Tunezja),...  27-05-2021 14:30:00
# 45  ITF MĘŻCZYŹNI - DEBEL: M15 Monastir (Tunezja),...  27-05-2021 15:30:00
# 46  ITF MĘŻCZYŹNI - DEBEL: M15 Novomoskovsk (Ukrai...  27-05-2021 15:00:00
# 47  ITF MĘŻCZYŹNI - DEBEL: M15 Novomoskovsk (Ukrai...  27-05-2021 15:00:00
# 48  ITF MĘŻCZYŹNI - DEBEL: M15 Novomoskovsk (Ukrai...  27-05-2021 15:30:00
# 49  ITF MĘŻCZYŹNI - DEBEL: M25 Kiseljak (Bośnia i ...  27-05-2021 15:30:00
# 50  ITF MĘŻCZYŹNI - DEBEL: M25 Kiseljak (Bośnia i ...  27-05-2021 17:00:00
# 51  ITF KOBIETY - DEBEL: W15 Antalya (Turcja), zie...  27-05-2021 14:00:00
# 52  ITF KOBIETY - DEBEL: W15 Antalya (Turcja), zie...  27-05-2021 14:00:00
# 53  ITF KOBIETY - DEBEL: W15 Heraklion 8 (Grecja),...  27-05-2021 14:30:00
# 54  ITF KOBIETY - DEBEL: W15 Monastir (Tunezja), t...  27-05-2021 14:30:00
# 55  ITF KOBIETY - DEBEL: W15 Monastir (Tunezja), t...  27-05-2021 15:00:00
# 56  ITF KOBIETY - DEBEL: W15 Monastir (Tunezja), t...  27-05-2021 15:00:00
# 57  ITF KOBIETY - DEBEL: W15 Monastir (Tunezja), t...  27-05-2021 15:30:00
# 58  ITF KOBIETY - DEBEL: W15 Santa Margarita de Mo...  27-05-2021 16:00:00
# 59  ITF KOBIETY - DEBEL: W15 Santa Margarita de Mo...  27-05-2021 16:00:00
# 60  ITF KOBIETY - DEBEL: W15 Shymkent 5 (Kazachsta...  27-05-2021 14:30:00
# 61  ITF KOBIETY - DEBEL: W15 Shymkent 5 (Kazachsta...  27-05-2021 15:00:00
# 62  ITF KOBIETY - DEBEL: W15 Sibenik 2 (Chorwacja)...  27-05-2021 14:30:00
# 63  ITF KOBIETY - DEBEL: W15 Sibenik 2 (Chorwacja)...  27-05-2021 14:30:00
# 64  ITF KOBIETY - DEBEL: W15 Sibenik 2 (Chorwacja)...  27-05-2021 14:30:00
# 65  ITF KOBIETY - DEBEL: W15 Sibenik 2 (Chorwacja)...  27-05-2021 15:15:00
# 66  ITF KOBIETY - DEBEL: W25 Liepaja (Łotwa), ziem...  27-05-2021 14:00:00
# 67  ITF KOBIETY - DEBEL: W25 Otocec (Słowenia), zi...  27-05-2021 14:30:00
# 68  ITF KOBIETY - DEBEL: W25 Otocec (Słowenia), zi...  27-05-2021 14:30:00
# 69  ITF KOBIETY - DEBEL: W25 Otocec (Słowenia), zi...  27-05-2021 14:30:00
#
#                                              player_1  \
# 0                                       Andrej Martin
# 1                                   Federico Delbonis
# 2                                         Taro Daniel
# 3                                        Hugo Dellien
# 4                                     Sebastian Korda
# 5                            Jaqueline Adina Cristian
# 6                                   Aleksandra Krunic
# 7                                  Barbora Krejcikova
# 8                                       Jule Niemeier
# 9                        Ivan Sabanov / Matej Sabanov
# 10                   Simone Bolelli / Maximo Gonzalez
# 11                                     Denis Yevseyev
# 12                                    Chun Hsin Tseng
# 13                                       Pedro Araujo
# 14                       Evan King / Goncalo Oliveira
# 15                 Riccardo Bonadio / Nino Serdarusic
# 16                        Pedro Araujo / Fabio Coelho
# 17                         Joao Victor Couto Loureiro
# 18                                  Yannik Steinegger
# 19                                Thomas John Fancutt
# 20                                    Arthur Bouquier
# 21                                      Rrezart Cungu
# 22                                      Zsombor Piros
# 23                                        Ines Bekrar
# 24                                        Alice Robbe
# 25                                    Amanda Carreras
# 26                                   Maria Bondarenko
# 27                                       Emilie Lindh
# 28                               Lucija Ciric Bagaric
# 29                                    Barbora Miklova
# 30                                  Anastasia Zarycka
# 31                                       Victoria Kan
# 32                        Ignacio Carou / Orlando Luz
# 33          Constant De La Bassetiere / Stuart Parker
# 34         Uladzimir Ignatik / Mircea Alexandru Jecan
# 35             Facundo Juarez / Tomas Lipovsek Puches
# 36              Juan Ignacio Galarza / Juan Pablo Paz
# 37                 Vlad Andrei Dancu / Vladimir Filip
# 38                              Runhao Hua / Ze Zhang
# 39                       Alafia Ayeni / Dominik Palan
# 40             Alexander Cozbinov / Francesco Vilardo
# 41                        Johannes Seeman / Eero Vasa
# 42                    Jonas Maier / Simonas Zukauskas
# 43                         Jacob Brumm / Yuta Kikuchi
# 44                   Eliakim Coulibaly / Luca Potenza
# 45                 Jeremy Beale / Thomas John Fancutt
# 46          Viacheslav Bielinskyi / Artem Podorozhnyi
# 47                       Tuna Altuna / Martins Podzus
# 48                     Wojciech Marek / Michał Mikula
# 49                    Gauthier Onclin / Leandro Riedi
# 50                  Hernan Casanova / Flemming Peters
# 51                    Manon Arcangioli / Dia Evtimova
# 52                             Fiona Ganz / Dabin Kim
# 53                 Julia Stamatova / Draginja Vukovic
# 54  Ralina Kalimullina / Kuliczkowa Jelizawieta Mo...
# 55                    Freya Christie / Lauren Proctor
# 56                     Dalayna Hewitt / Chiara Scholl
# 57        Kariann Pierre-Louis / Laetitia Pulchartova
# 58   Yvonne Cavalle-Reimers / Ana Lantigua De La Nuez
# 59               Celia Cervino Ruiz / Olivia Nicholls
# 60         Mariam Dalakishvili / Anastasiya Poplavska
# 61               Valeriya Olyanovskaya / Alina Silich
# 62                Leolia Jeanjean / Bojana Marinkovic
# 63                      Enola Chiesa / Federica Rossi
# 64                   Diana Martynov / Chantal Sauvant
# 65                    Jelena Milovanovic / Tara Wurth
# 66                     Lina Gjorczeska / Vanda Lukacs
# 67            Cristiana Ferrando / Diana Marcinkevica
# 68                   Ziva Falkner / Matilda Mutavdzic
# 69                     Destanee Aiava / Sada Nahimana
#
#                                              player_2 player_1_score_sets  \
# 0                                       Dusan Lajovic                   0
# 1                             Roberto Carballes Baena                   0
# 2                                       Quentin Halys                   0
# 3                                          Oscar Otte                   0
# 4                                  Yoshihito Nishioka                   0
# 5                                   Anhelina Kalinina                   0
# 6                                      Olga Goworcowa                   0
# 7                            Jekatierina Aleksandrowa                   0
# 8                                         Arantxa Rus                   0
# 9               Jonathan Erlich / Andriej Wasilewskij                   0
# 10                         Max Purcell / Luke Saville                   1
# 11                                    Nuno Borges 1:2                   1
# 12                               Filip Cristian Jianu                   0
# 13                                       Gastao Elias                   0
# 14                Pedro Cachin / Camilo Ugo Carabelli                   0
# 15                     Nuno Borges / Francisco Cabral                   0
# 16                       Julian Lenz / Roberto Quiroz                   0
# 17                                      Zsombor Velcz                   0
# 18                                      Otto Virtanen                   0
# 19                                     Seita Watanabe                   0
# 20                                          Roy Smith                   0
# 21                                    Francesco Forti                   0
# 22                                 Sebastian Prechtel                   0
# 23                                    Miharu Imanishi                   0
# 24                                      Chiraz Bechri                   0
# 25                                    Francesca Curmi                   0
# 26                                   Mihaela Djakovic                   0
# 27                                Oksana Selekhmeteva                   0
# 28                                      Tatiana Pieri                   0
# 29                                    Emeline Dartron                   0
# 30                                   Dalila Jakupovic                   0
# 31                                    Alexandra Vecic                   0
# 32                  Fletcher Scott / Daisuke Sumizawa                   0
# 33                          Jakub Paul / Bart Stevens                   0
# 34               Nicholas David Ionel / Stefan Palosi                   0
# 35          Oscar Jose Gutierrez / Cristian Rodriguez                   0
# 36               Vlad Andrei Dumitru / Nicolae Frunza                   0
# 37                         Simon Carr / Clement Tabur                   0
# 38                 Vasilios Caripi / Kelsey Stevenson                   0
# 39                     Rimpei Kawakami / Naoki Tajima                   0
# 40                  August Ehrnrooth / Karl Kiur Saar                   0
# 41                      Vladimir Ivanov / Yan Sabanin                   0
# 42               Luca Castelnuovo / Yannik Steinegger                   0
# 43                  Guy Orly Iradukunda / Louis Tessa                   0
# 44      Gustavo Heide / Alejo Lorenzo Lingua Lavallen                   0
# 45                      Yunseong Chung / Seongbin Sim                   0
# 46       Carlos Sanchez Jover / Jose Fco Vidal Azorin                   0
# 47                 Yurii Dzhavakian / Oleksii Krutykh                   0
# 48             Aleksandr Braynin / Georgii Kravchenko                   0
# 49  Gilbert Klier Junior / Matheus Pucinelli de Al...                   0
# 50                    Zvonimir Babic / Fabian Fallert                   0
# 51                          Mayuka Aikawa / Shuyue Ma                   0
# 52          Lola Marandel / Luisa Meyer Auf Der Heide                   0
# 53                    Julia Kimmelmann / Anna Popescu                   0
# 54            Emma Davis / Maria Paulina Perez Garcia                   0
# 55                       Kendra Bunch / Nadine Keller                   0
# 56                   Haruna Arakawa / Natsuho Arakawa                   0
# 57            Angelica Raggi / Eliessa Vanlangendonck                   0
# 58                Victoria Bosio / Justina Mikulskyte                   0
# 59                   Nicole Gadient / Valentina Ryser                   0
# 60                 Martyna Kubka / Zhibek Kulambayeva                   0
# 61            Tatyana Nikolenko / Aruzhan Sagandikova                   0
# 62                  Petra Marcinko / Natalia Szabanin                   0
# 63                        Sinja Kraus / Verena Meliss                   0
# 64            Nefisa Berberovic / Huergo Nicole Fossa                   0
# 65           Katerina Mandelikova / Ana Filipa Santos                   0
# 66                  Patricija Spaka / Daniela Vismane                   0
# 67                      Amina Anszba / Johana Markova                   0
# 68              Federica Di Sarra / Camilla Rosatello                   0
# 69              Martina Caregaro / Angelica Moratelli                   0
#
#    player_1_score_games player_1_score_points player_2_score_sets  \
# 0                     2                     0                   0
# 1                                                               0
# 2                     1                     0                   0
# 3                     1                     0                   0
# 4                                                               0
# 5                   4 0                    30                   1
# 6                     3                     0                   0
# 7                     6                     0                   0
# 8                                                               0
# 9                   3 2                    30                   1
# 10                  6 2                     0                   0
# 11                7 4 2                    15                   1
# 12                    1                     0                   0
# 13                                                              0
# 14                                                              0
# 15                                                              0
# 16                                                              0
# 17                                                              0
# 18                                                              0
# 19                                                              0
# 20                                                              0
# 21                                                              0
# 22                                                              0
# 23                                                              0
# 24                                                              0
# 25                                                              0
# 26                                                              0
# 27                                                              0
# 28                                                              0
# 29                                                              0
# 30                                                              0
# 31                                                              0
# 32                                                              0
# 33                                                              0
# 34                                                              0
# 35                                                              0
# 36                                                              0
# 37                                                              0
# 38                                                              0
# 39                                                              0
# 40                                                              0
# 41                                                              0
# 42                                                              0
# 43                                                              0
# 44                                                              0
# 45                                                              0
# 46                                                              0
# 47                                                              0
# 48                                                              0
# 49                                                              0
# 50                                                              0
# 51                                                              0
# 52                                                              0
# 53                                                              0
# 54                                                              0
# 55                                                              0
# 56                                                              0
# 57                                                              0
# 58                                                              0
# 59                                                              0
# 60                                                              0
# 61                                                              0
# 62                                                              0
# 63                                                              0
# 64                                                              0
# 65                                                              0
# 66                                                              0
# 67                                                              0
# 68                                                              0
# 69                                                              0
#
#    player_2_score_games player_2_score_points   serving player_1_nationality  \
# 0                     3                    15  player_1                  Svk
# 1                                                   NaN                  Arg
# 2                     3                     0  player_2                  Jpn
# 3                     2                     0  player_1                  Bol
# 4                                                   NaN                  Usa
# 5                   6 3                    40  player_2                  Rou
# 6                     1                     0  player_1                  Srb
# 7                     6                     0  player_1                  Cze
# 8                                                   NaN                  Ger
# 9                   6 1                    30  player_2                   /
# 10                  3 1                     0  player_2                   /
# 11                6 6 5                    30  player_2                  Kaz
# 12                    2                     0  player_1                  Tpe
# 13                                                  NaN                  Por
# 14                                                  NaN                   /
# 15                                                  NaN                   /
# 16                                                  NaN                   /
# 17                                                  NaN                  Bra
# 18                                                  NaN                  Sui
# 19                                                  NaN                  Aus
# 20                                                  NaN                  Fra
# 21                                                  NaN                  Mne
# 22                                                  NaN                  Hun
# 23                                                  NaN                  Alg
# 24                                                  NaN                  Fra
# 25                                                  NaN                  Gbr
# 26                                                  NaN                  Rus
# 27                                                  NaN                  Gbr
# 28                                                  NaN                  Cro
# 29                                                  NaN                  Cze
# 30                                                  NaN                  Cze
# 31                                                  NaN                  Rus
# 32                                                  NaN                   /
# 33                                                  NaN                   /
# 34                                                  NaN                   /
# 35                                                  NaN                   /
# 36                                                  NaN                   /
# 37                                                  NaN                   /
# 38                                                  NaN                   /
# 39                                                  NaN                   /
# 40                                                  NaN                   /
# 41                                                  NaN                   /
# 42                                                  NaN                   /
# 43                                                  NaN                   /
# 44                                                  NaN                   /
# 45                                                  NaN                   /
# 46                                                  NaN                   /
# 47                                                  NaN                   /
# 48                                                  NaN                   /
# 49                                                  NaN                   /
# 50                                                  NaN                   /
# 51                                                  NaN                   /
# 52                                                  NaN                   /
# 53                                                  NaN                   /
# 54                                                  NaN                   /
# 55                                                  NaN                   /
# 56                                                  NaN                   /
# 57                                                  NaN                   /
# 58                                                  NaN                   /
# 59                                                  NaN                   /
# 60                                                  NaN                   /
# 61                                                  NaN                   /
# 62                                                  NaN                   /
# 63                                                  NaN                   /
# 64                                                  NaN                   /
# 65                                                  NaN                   /
# 66                                                  NaN                   /
# 67                                                  NaN                   /
# 68                                                  NaN                   /
# 69                                                  NaN                   /
#
#    player_2_nationality player_1_rank player_2_rank  \
# 0                   Srb           119            39
# 1                   Esp            52            98
# 2                   Fra           112           222
# 3                   Ger           124           152
# 4                   Jpn            63            60
# 5                   Ukr           152           139
# 6                   Blr           212           138
# 7                   Rus            38            33
# 8                   Ned           216            84
# 9                    /          / 916            /
# 10                   /         589 /      278 / 412
# 11                  Por           390           275
# 12                  Rou           274           349
# 13                  Por           991           292
# 14                   /      475 / 316     295 / 310
# 15                   /      289 / 298    275 / 1000
# 16                   /     991 / 1229     269 / 276
# 17                  Hun                        1309
# 18                  Fin          1291           556
# 19                  Jpn           592          1218
# 20                  Usa          1049           552
# 21                  Ita          1706           421
# 22                  Ger           450           729
# 23                  Jpn                         503
# 24                  Tun           728           906
# 25                  Mlt           361          1167
# 26                  Srb           975           895
# 27                  Rus           696           540
# 28                  Ita                         506
# 29                  Fra           623           766
# 30                  Slo           404           298
# 31                  Ger           257           928
# 32                   /      957 / 333   1634 / 1085
# 33                   /     1655 / 577     669 / 833
# 34                   /      352 / 511     535 / 907
# 35                   /      558 / 618     414 / 507
# 36                   /      597 / 588         / 652
# 37                   /    1015 / 1669     581 / 579
# 38                   /      732 / 509         / 687
# 39                   /      874 / 910     951 / 664
# 40                   /      670 / 709        / 1873
# 41                   /         / 1195     706 / 849
# 42                   /        1788 /     717 / 1291
# 43                   /    1532 / 1173     842 / 832
# 44                   /      963 / 633    1416 / 703
# 45                   /     1532 / 592        409 /
# 46                   /        1873 /      566 / 560
# 47                   /          / 447     862 / 534
# 48                   /     653 / 1356    1193 / 497
# 49                   /      539 / 777     605 / 518
# 50                   /     391 / 2048            /
# 51                   /      625 / 659     889 / 419
# 52                   /      874 / 370            /
# 53                   /      684 / 722   1049 / 1265
# 54                   /             /      811 / 801
# 55                   /      676 / 863        / 1312
# 56                   /      883 / 636        380 /
# 57                   /          / 872     726 / 758
# 58                   /      410 / 655     445 / 562
# 59                   /         831 /     1062 / 587
# 60                   /      839 / 944     745 / 578
# 61                   /      772 / 977            /
# 62                   /      838 / 834            /
# 63                   /     1312 / 878     666 / 507
# 64                   /    1089 / 1225     550 / 689
# 65                   /      966 / 669        / 1154
# 66                   /      336 / 577         / 488
# 67                   /      425 / 283     325 / 403
# 68                   /      752 / 859     318 / 394
# 69                   /      244 / 436     306 / 437
#
#                                         player_1_link  \
# 0   https://www.flashscore.pl/zawodnik/martin-andr...
# 1   https://www.flashscore.pl/zawodnik/delbonis-fe...
# 2   https://www.flashscore.pl/zawodnik/daniel-taro...
# 3   https://www.flashscore.pl/zawodnik/dellien-hug...
# 4   https://www.flashscore.pl/zawodnik/korda-sebas...
# 5   https://www.flashscore.pl/zawodnik/cristian-ja...
# 6   https://www.flashscore.pl/zawodnik/krunic-alek...
# 7   https://www.flashscore.pl/zawodnik/krejcikova-...
# 8   https://www.flashscore.pl/zawodnik/niemeier-ju...
# 9   https://www.flashscore.pl/zawodnik/sabanov-iva...
# 10  https://www.flashscore.pl/zawodnik/bolelli-sim...
# 11  https://www.flashscore.pl/zawodnik/yevseyev-de...
# 12  https://www.flashscore.pl/zawodnik/tseng-chun-...
# 13  https://www.flashscore.pl/zawodnik/araujo-pedr...
# 14  https://www.flashscore.pl/zawodnik/king-evan/v...
# 15  https://www.flashscore.pl/zawodnik/bonadio-ric...
# 16  https://www.flashscore.pl/zawodnik/araujo-pedr...
# 17  https://www.flashscore.pl/zawodnik/loureiro-jo...
# 18  https://www.flashscore.pl/zawodnik/steinegger-...
# 19  https://www.flashscore.pl/zawodnik/fancutt-tho...
# 20  https://www.flashscore.pl/zawodnik/bouquier-ar...
# 21  https://www.flashscore.pl/zawodnik/cungu-rreza...
# 22  https://www.flashscore.pl/zawodnik/piros-zsomb...
# 23  https://www.flashscore.pl/zawodnik/bekrar-ines...
# 24  https://www.flashscore.pl/zawodnik/robbe-alice...
# 25  https://www.flashscore.pl/zawodnik/carreras-am...
# 26  https://www.flashscore.pl/zawodnik/bondarenko-...
# 27  https://www.flashscore.pl/zawodnik/lindh-emili...
# 28  https://www.flashscore.pl/zawodnik/ciric-bagar...
# 29  https://www.flashscore.pl/zawodnik/miklova-bar...
# 30  https://www.flashscore.pl/zawodnik/zarycka-ana...
# 31  https://www.flashscore.pl/zawodnik/kan-victori...
# 32  https://www.flashscore.pl/zawodnik/carou-ignac...
# 33  https://www.flashscore.pl/zawodnik/de-la-basse...
# 34  https://www.flashscore.pl/zawodnik/ignatik-ula...
# 35  https://www.flashscore.pl/zawodnik/juarez-facu...
# 36  https://www.flashscore.pl/zawodnik/galarza-jua...
# 37  https://www.flashscore.pl/zawodnik/dancu-vlad-...
# 38  https://www.flashscore.pl/zawodnik/hua-runhao/...
# 39  https://www.flashscore.pl/zawodnik/ayeni-alafi...
# 40  https://www.flashscore.pl/zawodnik/cozbinov-al...
# 41  https://www.flashscore.pl/zawodnik/seeman-joha...
# 42  https://www.flashscore.pl/zawodnik/jonas-maier...
# 43  https://www.flashscore.pl/zawodnik/brumm-jacob...
# 44  https://www.flashscore.pl/zawodnik/coulibaly-e...
# 45  https://www.flashscore.pl/zawodnik/beale-jerem...
# 46  https://www.flashscore.pl/zawodnik/bielinskyi-...
# 47  https://www.flashscore.pl/zawodnik/altuna-tuna...
# 48  https://www.flashscore.pl/zawodnik/marek-wojci...
# 49  https://www.flashscore.pl/zawodnik/onclin-gaut...
# 50  https://www.flashscore.pl/zawodnik/casanova-he...
# 51  https://www.flashscore.pl/zawodnik/arcangioli-...
# 52  https://www.flashscore.pl/zawodnik/ganz-fiona/...
# 53  https://www.flashscore.pl/zawodnik/stamatova-j...
# 54  https://www.flashscore.pl/zawodnik/kalimullina...
# 55  https://www.flashscore.pl/zawodnik/christie-fr...
# 56  https://www.flashscore.pl/zawodnik/hewitt-dala...
# 57  https://www.flashscore.pl/zawodnik/pierre-loui...
# 58  https://www.flashscore.pl/zawodnik/cavalle-rei...
# 59  https://www.flashscore.pl/zawodnik/cervino-rui...
# 60  https://www.flashscore.pl/zawodnik/dalakishvil...
# 61  https://www.flashscore.pl/zawodnik/olyanovskay...
# 62  https://www.flashscore.pl/zawodnik/jeanjean-le...
# 63  https://www.flashscore.pl/zawodnik/chiesa-enol...
# 64  https://www.flashscore.pl/zawodnik/martynov-di...
# 65  https://www.flashscore.pl/zawodnik/milovanovic...
# 66  https://www.flashscore.pl/zawodnik/gjorczeska-...
# 67  https://www.flashscore.pl/zawodnik/ferrando-cr...
# 68  https://www.flashscore.pl/zawodnik/falkner-ziv...
# 69  https://www.flashscore.pl/zawodnik/aiava-desta...
#
#                                         player_2_link player_1_eFortuna  \
# 0   https://www.flashscore.pl/zawodnik/lajovic-dus...               3.3
# 1   https://www.flashscore.pl/zawodnik/carballes-b...               1.5
# 2   https://www.flashscore.pl/zawodnik/halys-quent...              1.38
# 3   https://www.flashscore.pl/zawodnik/otte-oscar/...              2.55
# 4   https://www.flashscore.pl/zawodnik/nishioka-yo...              1.53
# 5   https://www.flashscore.pl/zawodnik/kalinina-an...              3.65
# 6   https://www.flashscore.pl/zawodnik/gworcowa-ol...              1.41
# 7   https://www.flashscore.pl/zawodnik/aleksandrow...              1.65
# 8   https://www.flashscore.pl/zawodnik/rus-arantxa...              2.02
# 9   https://www.flashscore.pl/zawodnik/erlich-jona...              1.72
# 10  https://www.flashscore.pl/zawodnik/purcell-max...              1.52
# 11  https://www.flashscore.pl/zawodnik/borges-nuno...               NaN
# 12  https://www.flashscore.pl/zawodnik/jianu-filip...              1.61
# 13  https://www.flashscore.pl/zawodnik/elias-gasta...                 7
# 14  https://www.flashscore.pl/zawodnik/cachin-pedr...              1.56
# 15  https://www.flashscore.pl/zawodnik/borges-nuno...              2.32
# 16  https://www.flashscore.pl/zawodnik/lenz-julian...              3.35
# 17  https://www.flashscore.pl/zawodnik/zsombor-vel...              3.35
# 18  https://www.flashscore.pl/zawodnik/virtanen-ot...               5.4
# 19  https://www.flashscore.pl/zawodnik/watanabe-se...              1.42
# 20  https://www.flashscore.pl/zawodnik/smith-roy/O...              2.11
# 21  https://www.flashscore.pl/zawodnik/forti-franc...               5.6
# 22  https://www.flashscore.pl/zawodnik/prechtel-se...              1.18
# 23  https://www.flashscore.pl/zawodnik/imanishi-mi...                 8
# 24  https://www.flashscore.pl/zawodnik/bechri-chir...              1.18
# 25  https://www.flashscore.pl/zawodnik/curmi-franc...              1.73
# 26  https://www.flashscore.pl/zawodnik/djakovic-mi...              1.72
# 27  https://www.flashscore.pl/zawodnik/selekhmetev...               7.8
# 28  https://www.flashscore.pl/zawodnik/pieri-tatia...              2.95
# 29  https://www.flashscore.pl/zawodnik/dartron-eme...               NaN
# 30  https://www.flashscore.pl/zawodnik/jakupovic-d...              1.56
# 31  https://www.flashscore.pl/zawodnik/vecic-alexa...              1.74
# 32  https://www.flashscore.pl/zawodnik/scott-fletc...               1.2
# 33  https://www.flashscore.pl/zawodnik/paul-jakub/...              2.27
# 34  https://www.flashscore.pl/zawodnik/ionel-nicho...              1.51
# 35  https://www.flashscore.pl/zawodnik/gutierrez-o...               2.2
# 36  https://www.flashscore.pl/zawodnik/dumitru-vla...               NaN
# 37  https://www.flashscore.pl/zawodnik/carr-simon/...              2.55
# 38  https://www.flashscore.pl/zawodnik/caripi-vasi...              1.09
# 39  https://www.flashscore.pl/zawodnik/kawakami-ri...               2.9
# 40  https://www.flashscore.pl/zawodnik/ehrnrooth-a...              1.17
# 41  https://www.flashscore.pl/zawodnik/ivanov-vlad...              3.05
# 42  https://www.flashscore.pl/zawodnik/castelnuovo...                 6
# 43  https://www.flashscore.pl/zawodnik/iradukunda-...              3.35
# 44  https://www.flashscore.pl/zawodnik/heide-gusta...              1.31
# 45  https://www.flashscore.pl/zawodnik/chung-yunse...              1.43
# 46  https://www.flashscore.pl/zawodnik/sanchez-jov...               4.8
# 47  https://www.flashscore.pl/zawodnik/dzhavakian-...               NaN
# 48  https://www.flashscore.pl/zawodnik/braynin-ale...               1.8
# 49  https://www.flashscore.pl/zawodnik/soares-klie...              2.14
# 50  https://www.flashscore.pl/zawodnik/babic-zvoni...              2.32
# 51  https://www.flashscore.pl/zawodnik/aikawa-mayu...              1.61
# 52  https://www.flashscore.pl/zawodnik/marandel-lo...              1.47
# 53  https://www.flashscore.pl/zawodnik/kimmelmann-...              2.07
# 54  https://www.flashscore.pl/zawodnik/davis-emma/...               6.8
# 55  https://www.flashscore.pl/zawodnik/bunch-kendr...              1.16
# 56  https://www.flashscore.pl/zawodnik/arakawa-har...               1.4
# 57  https://www.flashscore.pl/zawodnik/raggi-angel...               5.6
# 58  https://www.flashscore.pl/zawodnik/bosio-victo...               1.9
# 59  https://www.flashscore.pl/zawodnik/gadient-nic...               1.2
# 60  https://www.flashscore.pl/zawodnik/kubka-marty...                 5
# 61  https://www.flashscore.pl/zawodnik/nikolenko-t...              1.19
# 62  https://www.flashscore.pl/zawodnik/petra-marci...              1.85
# 63  https://www.flashscore.pl/zawodnik/kraus-sinja...              1.93
# 64  https://www.flashscore.pl/zawodnik/berberovic-...               4.4
# 65  https://www.flashscore.pl/zawodnik/mandelikova...              1.29
# 66  https://www.flashscore.pl/zawodnik/spaka-patri...              1.65
# 67  https://www.flashscore.pl/zawodnik/anszba-amin...               2.6
# 68  https://www.flashscore.pl/zawodnik/di-sarra-fe...               2.6
# 69  https://www.flashscore.pl/zawodnik/caregaro-ma...              1.57
#
#    player_2_eFortuna player_1_STS player_2_STS player_1_Betclic  \
# 0               1.36         3.25         1.35             3.45
# 1                2.7         1.45         2.75             1.41
# 2                3.1         1.37         3.05              NaN
# 3               1.52          2.5         1.52              2.5
# 4               2.65         1.45          2.7              1.4
# 5               1.29         3.55         1.27              3.3
# 6               2.95          1.4          2.9             1.41
# 7               2.31         1.67         2.15             1.68
# 8                1.8         1.95          1.8             2.02
# 9               2.13          1.7          2.1             1.69
# 10              2.48         1.52         2.45             1.51
# 11               NaN          NaN          NaN              NaN
# 12              2.27          1.6          2.2              NaN
# 13              1.09          6.4         1.08              6.4
# 14              2.34         1.52          2.3             1.54
# 15              1.57         2.25         1.55             2.29
# 16              1.29         3.25         1.27              3.3
# 17              1.26         3.35         1.27              3.3
# 18               1.1          5.5          1.1              5.2
# 19               2.6         1.42          2.6              NaN
# 20              1.62          2.1         1.62              NaN
# 21               1.1          5.6          1.1              5.4
# 22               4.1         1.18          4.1             1.18
# 23              1.03          8.1         1.03              NaN
# 24               4.2         1.18          4.1             1.18
# 25              1.95          1.8          1.9             1.77
# 26              1.96         1.72         1.95             1.71
# 27              1.04         7.45         1.05                7
# 28              1.33         2.95         1.32              2.9
# 29               NaN          NaN          NaN              NaN
# 30              2.33         1.52          2.3              NaN
# 31              2.02         1.72            2              1.7
# 32               3.9          1.2          3.9              NaN
# 33              1.54         2.25         1.55             2.25
# 34              2.33         1.52         2.35              1.5
# 35              1.57          2.2         1.57             2.18
# 36               NaN          NaN          NaN              NaN
# 37              1.43         2.55         1.42             2.55
# 38               5.8          1.1         5.75             1.09
# 39              1.34          2.9         1.35              2.9
# 40               4.2         1.17         4.25             1.17
# 41              1.32         3.05         1.32                3
# 42              1.08         6.05         1.08              5.8
# 43              1.27         3.35         1.27             3.25
# 44               3.1          1.3          3.1              1.3
# 45              2.55         1.42         2.55             1.42
# 46              1.14          4.8         1.14              NaN
# 47               NaN          NaN          NaN              NaN
# 48               1.9          1.8          1.9             1.77
# 49               1.6         2.15          1.6              NaN
# 50              1.52          2.3         1.52              2.3
# 51              2.14          1.6         2.15             1.59
# 52              2.44         1.47         2.45             1.46
# 53              1.65         2.05         1.65             2.05
# 54              1.06          6.8         1.06              6.4
# 55               4.4         1.16         4.35             1.16
# 56               2.7          1.4          2.7             1.39
# 57              1.09          5.7          1.1              5.4
# 58              1.78          1.9          1.8              NaN
# 59              3.95          1.2         3.95             1.23
# 60              1.12         5.05         1.12              NaN
# 61                 4          NaN          NaN              NaN
# 62              1.82         1.85          1.8             1.83
# 63              1.75         1.95         1.75             1.91
# 64              1.16         4.35         1.16              4.3
# 65               3.2          1.3          3.2              NaN
# 66              2.07         1.65         2.05             1.64
# 67              1.44         2.55         1.42             2.55
# 68              1.44         2.55         1.42             2.55
# 69              2.25         1.57         2.25             1.55
#
#    player_2_Betclic player_1_Betfan player_2_Betfan player_1_Pzbuk  \
# 0              1.32            3.45            1.31           3.45
# 1              2.95            1.39               3           1.42
# 2               NaN            1.36            3.15           1.36
# 3              1.54            2.59             1.5            2.5
# 4              2.95            1.44             2.8           1.45
# 5              1.34            3.75            1.27            3.7
# 6              2.95            1.38            3.05           1.39
# 7              2.19            1.61            2.33           1.66
# 8               1.8            2.05            1.77           2.05
# 9               2.1            1.69            2.17            1.8
# 10             2.45            1.51            2.56           1.39
# 11              NaN             NaN             NaN            NaN
# 12              NaN            1.61            2.27            1.6
# 13             1.08               7            1.09            NaN
# 14             2.31            1.57            2.37           1.54
# 15             1.56            2.34            1.58            2.4
# 16             1.29            3.45             1.3            NaN
# 17             1.25            3.36            1.26           3.45
# 18              1.1            5.48             1.1              6
# 19              NaN            1.42             2.6           1.42
# 20              NaN            2.11            1.62           1.86
# 21             1.09            5.58             1.1            NaN
# 22                4            1.18            4.09            NaN
# 23              NaN             8.1            1.03              9
# 24             3.95            1.18            4.16           1.17
# 25             1.87            1.73            1.95            1.8
# 26             1.94            1.72            1.96           1.71
# 27             1.04            7.46            1.05            8.5
# 28             1.32            2.96            1.33           3.05
# 29              NaN             NaN             NaN            NaN
# 30              NaN            1.52            2.31            1.5
# 31             1.96            1.71            1.98            NaN
# 32              NaN             1.2             3.9            NaN
# 33             1.53            2.27            1.54           2.45
# 34              2.3             NaN             NaN           1.51
# 35             1.56             NaN             NaN           2.25
# 36              NaN             NaN             NaN            NaN
# 37             1.42             NaN             NaN            NaN
# 38              5.6             NaN             NaN           1.07
# 39             1.33            2.92            1.34           2.85
# 40              4.1            1.17            4.24            NaN
# 41             1.31            3.03            1.32            NaN
# 42             1.08            6.03            1.08            NaN
# 43             1.26            3.33            1.27           3.45
# 44             3.05            1.31            3.08           1.29
# 45             2.55            1.43            2.56           1.42
# 46              NaN             NaN             NaN            NaN
# 47              NaN             NaN             NaN            NaN
# 48             1.87             NaN             NaN            NaN
# 49              NaN            2.14             1.6            NaN
# 50             1.51            2.32            1.52            NaN
# 51             2.12            1.61            2.14           1.66
# 52             2.41            1.47            2.44           1.46
# 53             1.64            2.07            1.65            NaN
# 54             1.06             6.8            1.06           7.75
# 55              4.2            1.16            4.36            NaN
# 56             2.65             1.4            2.68           1.37
# 57             1.09            5.69            1.09            NaN
# 58              NaN            1.89            1.78            NaN
# 59              3.5             1.2            3.94            NaN
# 60              NaN            5.07            1.12           4.85
# 61              NaN             NaN             NaN            NaN
# 62              1.8            1.85            1.82            NaN
# 63             1.73            1.93            1.75           1.95
# 64             1.16            4.37            1.16            4.5
# 65              NaN            1.29            3.18            1.3
# 66             2.05            1.65            2.07            NaN
# 67             1.42            2.56            1.43           2.65
# 68             1.42            2.57            1.43           2.65
# 69              2.2            1.56            2.23           1.55
#
#    player_2_Pzbuk player_1_Lvbet player_2_Lvbet player_1_Totolotek  \
# 0            1.32           3.15           1.31               3.04
# 1            2.95           1.37           2.85               1.41
# 2            3.15           1.37            2.9               1.35
# 3            1.54            2.5           1.48               2.29
# 4            2.85           1.42           2.65               1.41
# 5            1.27            3.5           1.27               3.04
# 6               3           1.38           2.85                1.4
# 7             2.3            1.7           2.05                1.7
# 8            1.83           1.96           1.76                  2
# 9            1.95            NaN            NaN               1.74
# 10            2.8           1.47            2.5               1.48
# 11            NaN            NaN            NaN               5.73
# 12           2.25           1.58           2.19               1.55
# 13            NaN            6.6           1.06               5.47
# 14            2.3           1.51            2.3               1.53
# 15            1.5            2.2           1.56               2.14
# 16            NaN           3.25           1.27               3.28
# 17           1.25           3.45           1.25                NaN
# 18            1.1            5.3           1.11                NaN
# 19           2.65           1.42            2.6               1.43
# 20           1.83           2.19           1.58               2.05
# 21            NaN            6.2           1.07                NaN
# 22            NaN           1.17           4.25                NaN
# 23           1.02            8.4           1.03                NaN
# 24           4.25           1.19              4                NaN
# 25            1.9           1.77           1.91               1.78
# 26              2           1.74           1.94                1.7
# 27           1.03            7.7           1.04               7.61
# 28           1.31           3.05           1.31               2.98
# 29            NaN            NaN            NaN                NaN
# 30            2.4           1.56            2.2                1.6
# 31            NaN           1.71           1.98               1.72
# 32            NaN            NaN            NaN                NaN
# 33           1.47            2.4           1.47                NaN
# 34           2.35           1.51           2.35                NaN
# 35           1.55            NaN            NaN                NaN
# 36            NaN            NaN            NaN                NaN
# 37            NaN            NaN            NaN                NaN
# 38            6.5           1.08            6.1                NaN
# 39           1.36            2.9           1.34                NaN
# 40            NaN           1.13           4.85                NaN
# 41            NaN            3.2           1.28                NaN
# 42            NaN              7           1.05                NaN
# 43           1.25           3.35           1.26                NaN
# 44            3.2            1.3            3.1                NaN
# 45           2.65           1.43           2.55                NaN
# 46            NaN           4.85           1.13                NaN
# 47            NaN            NaN            NaN                NaN
# 48            NaN           1.79           1.89                NaN
# 49            NaN            2.4           1.47                NaN
# 50            NaN           2.35           1.51                NaN
# 51            2.1           1.64           2.09                NaN
# 52            2.5           1.47            2.4                NaN
# 53            NaN           2.07           1.65                NaN
# 54           1.04            7.2           1.05                NaN
# 55            NaN           1.15            4.5                NaN
# 56            2.8           1.39           2.65                NaN
# 57            NaN            6.1           1.08                NaN
# 58            NaN            NaN            NaN                NaN
# 59            NaN           1.16           4.35                NaN
# 60           1.13            5.3           1.11               4.33
# 61            NaN            NaN            NaN               1.18
# 62            NaN            NaN            NaN                NaN
# 63           1.76           2.07           1.65                NaN
# 64           1.15           4.35           1.16                NaN
# 65           3.15           1.27           3.25                NaN
# 66            NaN            NaN            NaN                NaN
# 67           1.41           2.55           1.43                NaN
# 68           1.42           2.55           1.43                NaN
# 69           2.25           1.56            2.2                NaN
#
#    player_2_Totolotek
# 0                1.33
# 1                2.69
# 2                2.94
# 3                1.55
# 4                2.69
# 5                1.33
# 6                2.73
# 7                2.03
# 8                1.72
# 9                1.98
# 10               2.47
# 11               1.09
# 12               2.24
# 13                1.1
# 14               2.28
# 15                1.6
# 16               1.27
# 17                NaN
# 18                NaN
# 19               2.54
# 20               1.65
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25               1.88
# 26               1.98
# 27               1.04
# 28               1.32
# 29                NaN
# 30               2.14
# 31               1.96
# 32                NaN
# 33                NaN
# 34                NaN
# 35                NaN
# 36                NaN
# 37                NaN
# 38                NaN
# 39                NaN
# 40                NaN
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# 46                NaN
# 47                NaN
# 48                NaN
# 49                NaN
# 50                NaN
# 51                NaN
# 52                NaN
# 53                NaN
# 54                NaN
# 55                NaN
# 56                NaN
# 57                NaN
# 58                NaN
# 59                NaN
# 60               1.16
# 61               4.07
# 62                NaN
# 63                NaN
# 64                NaN
# 65                NaN
# 66                NaN
# 67                NaN
# 68                NaN
# 69                NaN

# %%
data.dtypes
# Out:
# event                    object
# match_time               object
# player_1                 object
# player_2                 object
# player_1_score_sets      object
# player_1_score_games     object
# player_1_score_points    object
# player_2_score_sets      object
# player_2_score_games     object
# player_2_score_points    object
# serving                  object
# player_1_nationality     object
# player_2_nationality     object
# player_1_rank            object
# player_2_rank            object
# player_1_link            object
# player_2_link            object
# player_1_eFortuna        object
# player_2_eFortuna        object
# player_1_STS             object
# player_2_STS             object
# player_1_Betclic         object
# player_2_Betclic         object
# player_1_Betfan          object
# player_2_Betfan          object
# player_1_Pzbuk           object
# player_2_Pzbuk           object
# player_1_Lvbet           object
# player_2_Lvbet           object
# player_1_Totolotek       object
# player_2_Totolotek       object
# dtype: object

# %%
# Hand-pick non-numeric columns
character_columns = ['event', 'match_time', 'player_1', 'player_2', 'player_1_score_games', 'player_2_score_games',
                    'player_1_score_points', 'player_2_score_points', 'serving', 'player_1_nationality',
                    'player_2_nationality', 'player_1_rank', 'player_2_rank', 'player_1_link', 'player_2_link']

# Note that `player_1_score_games` (and `player_2_score_games`) are not integers, because it contains games won
# in the subsequent sets, separated by a space, and `player_1_score_points` (and `player_2_score_points`) is not
# an integer column either, because it may contain 'A' (advantage).
# `player_1_rank` and `player_2_rank` are also not integers, since for doubles they contain an expression 'x / y'.

# Convert numberic (float/integer) columns to their proper types
for col in data.drop(character_columns, axis = 1).columns:
    data[col] = pd.to_numeric(data[col], downcast = 'integer')

# %%
data.dtypes
# Out:
# event                     object
# match_time                object
# player_1                  object
# player_2                  object
# player_1_score_sets         int8
# player_1_score_games      object
# player_1_score_points     object
# player_2_score_sets         int8
# player_2_score_games      object
# player_2_score_points     object
# serving                   object
# player_1_nationality      object
# player_2_nationality      object
# player_1_rank             object
# player_2_rank             object
# player_1_link             object
# player_2_link             object
# player_1_eFortuna        float64
# player_2_eFortuna        float64
# player_1_STS             float64
# player_2_STS             float64
# player_1_Betclic         float64
# player_2_Betclic         float64
# player_1_Betfan          float64
# player_2_Betfan          float64
# player_1_Pzbuk           float64
# player_2_Pzbuk           float64
# player_1_Lvbet           float64
# player_2_Lvbet           float64
# player_1_Totolotek       float64
# player_2_Totolotek       float64
# dtype: object

# %%
# Export the data, naming the file after the time scraping was finished
scraping_time = scraping_time.strftime("%d%m%y_%H%M%S")
data.to_csv('data_' + scraping_time + '.csv', index = False)

# %%
# Note: the retrieved match result would not be correct for the matches that are finished. However, since we are 
# interested in the matches that one can bet, we filter out the ended matches.
